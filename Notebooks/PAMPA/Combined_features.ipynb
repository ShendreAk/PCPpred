# %%
#Starts from here
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor, ExtraTreesRegressor
from sklearn.linear_model import LinearRegression, LogisticRegression  # LogisticRegression is not used for regression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor
import xgboost as xgb
import lightgbm as lgb
from sklearn.model_selection import KFold, GridSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler 
from scipy.stats import pearsonr, spearmanr
from sklearn.model_selection import train_test_split
from tqdm import tqdm

def remove_low_variance_columns(df, threshold=0.005):
    # df = df.drop(['ID','SMILES','Permeability'],axis=1)
    variances = df.var()
    
    # Identify columns with variance below the threshold
    low_variance_columns = variances[variances < threshold].index.tolist()
    
    df_cleaned = df.drop(columns=low_variance_columns)
    
    return df_cleaned, low_variance_columns

def features(df, target_column='Permeability', threshold=0.9):
    correlation_matrix = df.corr()
    
    features_to_drop = set()
    
    for feature in correlation_matrix.columns:
        if feature == target_column:
            continue 
        target_corr = correlation_matrix[target_column][feature]
        
        for other_feature in correlation_matrix.columns:
            if other_feature == feature or other_feature == target_column:
                continue
            
            if abs(correlation_matrix[feature][other_feature]) > threshold:
                other_target_corr = correlation_matrix[target_column][other_feature]

                if abs(other_target_corr) < abs(target_corr):
                    features_to_drop.add(other_feature)
                else:
                    features_to_drop.add(feature)
    selected_features = [col for col in df.columns if col not in features_to_drop and col != target_column]
    
    return selected_features

# %%
#Combined features and then selection

df_desc_train = pd.read_csv('/home/users/akshay/PCPpred/PAMPA/features/Descriptors/Train_2d_3d_all_descriptors.csv')
df_train = df_desc_train.sort_values(by='ID')
df_train =df_train.dropna()
train = df_train.drop(['ID','SMILES'],axis=1)
train = train.select_dtypes(include=['number'])
train, _ = remove_low_variance_columns(train)
selected_features = features(train, "Permeability")
df_desc_train = pd.concat( [df_train[['ID','SMILES','Permeability']],df_train[selected_features] ], axis=1)
df_desc_test = pd.read_csv('/home/users/akshay/PCPpred/PAMPA/features/Descriptors/Test_2d_3d_all_descriptors.csv')
df_desc_test = df_desc_test.sort_values(by='ID')
df_desc_test =df_desc_test.dropna()
df_desc_test =  df_desc_test[df_desc_train.columns]


# Fingerprints
df_fp_train = pd.read_csv('/home/users/akshay/PCPpred/PAMPA/features/Fingerprints/Train/All_fingerprints_train.csv')
df_train = df_fp_train.sort_values(by='ID')
df_train = df_train.dropna()
train = df_train.drop(['ID','SMILES'],axis=1)
train = train.select_dtypes(include=['number'])
train, _ = remove_low_variance_columns(train)
selected_features = features(train, "Permeability")
df_fp_train = pd.concat( [df_train[['ID','SMILES','Permeability']],df_train[selected_features] ], axis=1)
df_fp_test = pd.read_csv('/home/users/akshay/PCPpred/PAMPA/features/Fingerprints/Test/All_fingerprints_test.csv')
df_fp_test = df_fp_test.sort_values(by='ID')
df_fp_test = df_fp_test.dropna()
df_fp_test =  df_fp_test[df_fp_train.columns]


#Smiles Embeddings
df_emb_train = pd.read_csv('/home/users/akshay/PCPpred/PAMPA/features/Embeddings/Train_MoLFormer-XL-both-10pct_model_1_fine_tuned_embeddings.csv')
df_train = df_emb_train.sort_values(by='ID')
df_train = df_train.dropna()
train = df_train.drop(['ID','SMILES'],axis=1)
train = train.select_dtypes(include=['number'])
train, _ = remove_low_variance_columns(train)
selected_features = features(train, "Permeability")
df_emb_train = pd.concat( [df_train[['ID','SMILES','Permeability']],df_train[selected_features] ], axis=1)
df_emb_test = pd.read_csv('/home/users/akshay/PCPpred/PAMPA/features/Embeddings/Test_MoLFormer-XL-both-10pct_model_1_fine_tuned_embeddings.csv')
df_emb_test = df_emb_test.sort_values(by='ID')
df_emb_test = df_emb_test.dropna()
df_emb_test =  df_emb_test[df_emb_train.columns]

#ATomic features
df_atomic_train = pd.read_csv('/home/users/akshay/PCPpred/PAMPA/features/Atomic/Train_all_atomic_desc.csv')
df_train = df_atomic_train.sort_values(by='ID')
df_train = df_train.dropna()
train = df_train.drop(['ID','SMILES'],axis=1)
train = train.select_dtypes(include=['number'])
train, _ = remove_low_variance_columns(train)
selected_features = features(train, "Permeability")
df_atomic_train = pd.concat( [df_train[['ID','SMILES','Permeability']],df_train[selected_features] ], axis=1)
# df_atomic_train =pd.concat( [df_train['SMILES'], df_train.select_dtypes(include=['number'])], axis=1)
df_atomic_test = pd.read_csv('/home/users/akshay/PCPpred/PAMPA/features/Atomic/Test_all_atomic_desc.csv')
df_atomic_test = df_atomic_test.sort_values(by='ID')
df_atomic_test = df_atomic_test.dropna()
df_atomic_test =  df_atomic_test[df_atomic_train.columns]


print('XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX')
print('Data Loading completed')
print('XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX')
df_fp_test = df_fp_test[df_fp_test['ID'].isin(df_desc_test['ID'])]
df_fp_train = df_fp_train[df_fp_train['ID'].isin(df_desc_train['ID'])]

df_emb_test = df_emb_test[df_emb_test['ID'].isin(df_desc_test['ID'])]
df_emb_train = df_emb_train[df_emb_train['ID'].isin(df_desc_train['ID'])]

df_atomic_test = df_atomic_test[df_atomic_test['ID'].isin(df_desc_test['ID'])]
df_atomic_train = df_atomic_train[df_atomic_train['ID'].isin(df_desc_train['ID'])]

print(df_desc_train.shape)
print(df_desc_test.shape)
print(df_fp_train.shape)
print(df_fp_test.shape)
print(df_emb_train.shape)
print(df_emb_test.shape)
print(df_atomic_train.shape)
print(df_atomic_test.shape)
# Out:
# /tmp/ipykernel_3723516/3312508411.py:3: DtypeWarning: Columns (1275,1277,1280,1285,1292,1298,1304,1354,1356,1359,1364,1371,1377,1383,1579,1580,1581,1583,1584,1590,1595,1596,1597) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_desc_train = pd.read_csv('/home/users/akshay/PCPpred/PAMPA/features/Descriptors/Train_2d_3d_all_descriptors.csv')
# /tmp/ipykernel_3723516/3312508411.py:11: DtypeWarning: Columns (1275,1277,1292,1298,1354,1356,1371,1377,1579,1580,1581,1583,1584,1595,1596,1597) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_desc_test = pd.read_csv('/home/users/akshay/PCPpred/PAMPA/features/Descriptors/Test_2d_3d_all_descriptors.csv')
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# Data Loading completed
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# (5568, 271)
# (1392, 271)
# (5568, 1128)
# (1392, 1128)
# (5568, 758)
# (1392, 758)
# (5568, 12)
# (1392, 12)

# %%
merge_keys = ['ID', 'SMILES', 'Permeability']

merged_train = df_desc_train.merge(df_fp_train, on=merge_keys)
merged_train = merged_train.merge(df_emb_train, on=merge_keys)
merged_train = merged_train.merge(df_atomic_train, on=merge_keys)

merged_test = df_desc_test.merge(df_fp_test, on=merge_keys)
merged_test = merged_test.merge(df_emb_test, on=merge_keys)
merged_test = merged_test.merge(df_atomic_test, on=merge_keys)

# %%
X_train = merged_train.drop(columns=['ID', 'SMILES']).select_dtypes(include=['number'])
selected_final_features = features(X_train, target_column='Permeability')

train = pd.concat([merged_train[['ID', 'SMILES', 'Permeability']], X_train[selected_final_features]], axis=1)
test = merged_test[train.columns] 

print('selected_final_features', selected_final_features )
print("Final Train shape:", train.shape)
print("Final Test shape:", test.shape)
# Out:
# selected_final_features ['MinEStateIndex', 'qed', 'SPS', 'FpDensityMorgan1', 'BCUT2D_MWHI', 'AvgIpc', 'BalabanJ_x', 'Ipc', 'EState_VSA11', 'VSA_EState10', 'fr_Ar_N', 'fr_alkyl_halide', 'fr_allylic_oxid', 'fr_aryl_methyl', 'fr_methoxy', 'fr_morpholine', 'fr_para_hydroxylation', 'fr_piperdine', 'fr_priamide', 'AdjacencyMatrix.6', 'AdjacencyMatrix.9', 'AdjacencyMatrix.11', 'AATS', 'AATS.3', 'AATS.4', 'AATS.10', 'AATS.23', 'AATS.24', 'AATS.26', 'AATS.27', 'AATS.28', 'AATS.32', 'AATS.33', 'AATS.34', 'AATS.40', 'AATS.48', 'AATS.96', 'AATS.97', 'ATSC.2', 'ATSC.5', 'ATSC.7', 'ATSC.8', 'ATSC.12', 'ATSC.13', 'ATSC.14', 'ATSC.15', 'ATSC.16', 'ATSC.17', 'ATSC.20', 'ATSC.21', 'ATSC.22', 'ATSC.23', 'ATSC.24', 'ATSC.25', 'ATSC.26', 'ATSC.29', 'ATSC.30', 'ATSC.32', 'ATSC.37', 'ATSC.44', 'ATSC.50', 'ATSC.73', 'ATSC.76', 'ATSC.80', 'ATSC.84', 'ATSC.92', 'ATSC.96', 'ATSC.105', 'ATSC.106', 'AATSC.9', 'AATSC.11', 'AATSC.15', 'AATSC.16', 'AATSC.36', 'AATSC.43', 'AATSC.57', 'AATSC.60', 'GATS.1', 'GATS.3', 'GATS.4', 'GATS.5', 'GATS.12', 'GATS.13', 'GATS.18', 'GATS.27', 'GATS.59', 'GATS.70', 'GATS.71', 'GATS.77', 'BCUT.3', 'BCUT.4', 'Chi.4', 'AtomTypeEState.10', 'AtomTypeEState.31', 'AtomTypeEState.96', 'AtomTypeEState.106', 'AtomTypeEState.127', 'AtomTypeEState.129', 'AtomTypeEState.131', 'AtomTypeEState.170', 'AtomTypeEState.173', 'AtomTypeEState.271', 'EtaVEMCount.6', 'EtaFunctionalityIndex.1', 'InformationContent.1', 'LogS', 'MolecularDistanceEdge.7', 'RingCount.52', 'RingCount.64', 'RingCount.72', 'ALogP', 'AATS3m', 'AATS5v', 'AATS3i', 'AATS4i', 'AATS5i', 'AATS8i', 'AATS0s', 'AATS2s', 'AATS3s', 'AATS4s', 'AATS7s', 'ATSC6c', 'ATSC3m', 'ATSC6m', 'ATSC1e', 'ATSC5e', 'ATSC3p', 'ATSC4p', 'ATSC5p', 'ATSC2i', 'ATSC3i', 'ATSC8i', 'ATSC1s', 'ATSC4s', 'ATSC6s', 'ATSC7s', 'AATSC1m', 'AATSC5v', 'AATSC8v', 'AATSC1i', 'GATS7c', 'GATS8c', 'GATS6s', 'VE3_DzZ', 'VE1_Dzm', 'VE1_Dzp', 'VE3_Dzp', 'VR2_Dzi', 'VE1_Dzs', 'VE3_Dzs', 'VR1_Dzs', 'BCUTp-1l', 'BCUTp-1h', 'SpMax1_Bhs', 'SpMax2_Bhs', 'SpMax4_Bhs', 'SpMax5_Bhs', 'SpMax7_Bhs', 'SpMin7_Bhs', 'SCH-6', 'CrippenLogP', 'EE_Dt', 'VE1_Dt', 'VE3_Dt', 'VR2_Dt', 'VR3_Dt', 'nHBint4', 'nHBint7', 'nHBint10', 'SHBint6', 'SssCH2', 'minHBint2', 'minHBint3', 'minHBint4', 'minHBint5', 'minHBint7', 'minHBint8', 'minHBint9', 'minHBint10', 'minHsOH', 'minHCsatu', 'minsCH3', 'minssCH2', 'mindsCH', 'minssssC', 'minsNH2', 'minssNH', 'minsssN', 'maxHBint2', 'maxHBint3', 'maxHBint5', 'maxHBint6', 'maxHBint7', 'maxHBint8', 'maxHBint9', 'maxHBint10', 'maxsCH3', 'maxssCH2', 'maxssNH', 'maxsssN', 'hmin', 'LipoaffinityIndex', 'IC5', 'MIC0', 'nAtomLAC', 'MDEC-11', 'MDEC-12', 'MDEC-13', 'MDEC-22', 'MDEC-23', 'MDEC-33', 'MDEN-12', 'MDEN-22', 'MLFER_A', 'nFRing', 'nTRing', 'nHeteroRing', 'RotBtFrac', 'LipinskiFailures', 'VR2_D', 'XLogP', '3d_rdkit_5', '3d_rdkit_9', '3d_rdkit_10', '3d_rdkit_11', 'TDB9u', 'TDB1m', 'TDB3m', 'TDB4m', 'TDB5m', 'TDB7m', 'TDB10m', 'TDB3v', 'TDB8p', 'TDB9p', 'TDB2s', 'TDB4s', 'TDB5s', 'TDB6s', 'TDB7s', 'TDB8s', 'TDB9s', 'TDB10s', 'RPCS', 'RNCS', 'LOBMAX', 'LOBMIN', 'MOMI-XY', 'geomShape', 'RDF55p', 'P1m', 'Dv', 'L3p', 'Ki', 'Morgan_fp_2', 'Morgan_fp_5', 'Morgan_fp_13', 'Morgan_fp_19', 'Morgan_fp_42', 'Morgan_fp_84', 'Morgan_fp_94', 'Morgan_fp_109', 'Morgan_fp_113', 'Morgan_fp_115', 'Morgan_fp_126', 'Morgan_fp_130', 'Morgan_fp_160', 'Morgan_fp_167', 'Morgan_fp_174', 'Morgan_fp_216', 'Morgan_fp_219', 'Morgan_fp_231', 'Morgan_fp_250', 'Morgan_fp_253', 'Morgan_fp_328', 'Morgan_fp_334', 'Morgan_fp_355', 'Morgan_fp_370', 'Morgan_fp_400', 'Morgan_fp_444', 'Morgan_fp_460', 'Morgan_fp_476', 'Morgan_fp_523', 'Morgan_fp_534', 'Morgan_fp_545', 'Morgan_fp_561', 'Morgan_fp_562', 'Morgan_fp_619', 'Morgan_fp_632', 'Morgan_fp_668', 'Morgan_fp_675', 'Morgan_fp_684', 'Morgan_fp_687', 'Morgan_fp_689', 'Morgan_fp_695', 'Morgan_fp_725', 'Morgan_fp_749', 'Morgan_fp_752', 'Morgan_fp_784', 'Morgan_fp_809', 'Morgan_fp_820', 'Morgan_fp_832', 'Morgan_fp_878', 'Morgan_fp_893', 'Morgan_fp_914', 'Morgan_fp_919', 'Morgan_fp_963', 'Morgan_fp_978', 'Mor ...
# Final Train shape: (5568, 2141)
# Final Test shape: (1392, 2141)

# %%
def train_and_test_predict(models, X_train, y_train, X_test, y_test):
    kf = KFold(n_splits=5, shuffle=True, random_state=101)
    results = {}
    predictions = []  

    for model in models:
        model_name = model.__class__.__name__
        predictions_train = []
        actual_y_train = []

        test_predictions_folds = []

        

        for train_index, val_index in kf.split(X_train):
            X_train_fold, X_val_fold = X_train.iloc[train_index], X_train.iloc[val_index]
            y_train_fold, y_val_fold = y_train.iloc[train_index], y_train.iloc[val_index]

            model.fit(X_train_fold, y_train_fold)

            y_pred_fold = model.predict(X_val_fold)
            y_pred_fold = np.clip(y_pred_fold, -10, -3.9)
            predictions_train.extend(y_pred_fold)
            actual_y_train.extend(y_val_fold)

            predictions_test_fold = model.predict(X_test)
            predictions_test_fold = np.clip(predictions_test_fold, -10, -3.9)
            test_predictions_folds.append(predictions_test_fold)


        mse_train = mean_squared_error(actual_y_train, predictions_train)
        mae_train = mean_absolute_error(actual_y_train, predictions_train)
        rmse_train = np.sqrt(mse_train)
        r2_train = r2_score(actual_y_train, predictions_train)
        pearson_train, _ = pearsonr(actual_y_train, predictions_train)
        spearman_train, _ = spearmanr(actual_y_train, predictions_train)


        predictions_test_mean = np.mean(test_predictions_folds, axis=0)
        predictions_test_std = np.std(test_predictions_folds, axis=0)

        mse_test = mean_squared_error(y_test, predictions_test_mean)
        mae_test = mean_absolute_error(y_test, predictions_test_mean)
        rmse_test = np.sqrt(mse_test)
        r2_test = r2_score(y_test, predictions_test_mean)
        print(r2_test)
        pearson_test, _ = pearsonr(y_test, predictions_test_mean)
        spearman_test, _ = spearmanr(y_test, predictions_test_mean)
        
        

        predictions.append({
            'Model': model_name,
            'Y Train pred': predictions_train,
            'Y Test actual': y_test,
            'Test prediction folds': test_predictions_folds,
            'Test Predictions Mean': predictions_test_mean,
            'Test Predictions Std': predictions_test_std,

        })

        results[model_name] = {
            'Train MSE (5 fold cv)': f"{mse_train:.4f}",
            'Train MAE (5 fold cv)': f"{mae_train:.4f}",
            'Train RMSE (5 fold cv)': f"{rmse_train:.4f}",
            'Train RMSE (5 fold cv)': f"{rmse_train:.4f}",
            'Train R2 (5 fold cv)': f"{r2_train:.4f}",
            'Train PCC (5 fold cv)': f"{pearson_train:.4f}",
            'Train SCC (5 fold cv)': f"{spearman_train:.4f}",
            'Test MSE': f"{mse_test:.4f}",
            'Test MAE': f"{mae_test:.4f}",
            'Test RMSE': f"{rmse_test:.4f}",
            'Test R2': f"{r2_test:.4f}",
            'Test Pearson Correlation': f"{pearson_test:.4f}",
            'Test Spearman Correlation': f"{spearman_test:.4f}",
        }

    results_df = pd.DataFrame(results).T
    predictions_df = pd.DataFrame(predictions)

    return results_df, predictions_df

# %%
X_train = train.drop(['ID','SMILES','Permeability'],axis=1)
y_train = train['Permeability']
print("X_train shape: ",X_train.shape)
print("y_train shape: ",y_train.shape)
print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
X_test = test[X_train.columns]
y_test = test['Permeability']
print("X_test shape: ",X_test.shape)
print("y_test shape: ",y_test.shape)
print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_train = pd.DataFrame(X_train_scaled, columns=X_train.columns, index=X_train.index)
X_test = pd.DataFrame(X_test_scaled, columns=X_test.columns, index=X_test.index)
models = [
    lgb.LGBMRegressor(objective='regression',metric='rmse',boosting_type='gbdt',num_leaves=31,learning_rate=0.05,random_state=101),
    DecisionTreeRegressor(random_state=101),
    RandomForestRegressor(n_jobs=-1, random_state=101),
    GradientBoostingRegressor(random_state=101),
    AdaBoostRegressor(random_state=101),
    xgb.XGBRegressor(random_state=101),
    ExtraTreesRegressor(n_jobs=-1, n_estimators=100, random_state=101),
    LinearRegression(), 
    KNeighborsRegressor(n_neighbors=3),
    SVR(),  
    MLPRegressor(random_state=101)
]
result_df, prediction_df = train_and_test_predict(models, X_train,y_train, X_test,  y_test)
result_df
# Out:
# X_train shape:  (5568, 2138)
# y_train shape:  (5568,)
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# X_test shape:  (1392, 2138)
# y_test shape:  (1392,)
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.073405 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 252943
# [LightGBM] [Info] Number of data points in the train set: 4454, number of used features: 2104
# [LightGBM] [Info] Start training from score -5.747051
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.159816 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 252956
# [LightGBM] [Info] Number of data points in the train set: 4454, number of used features: 2106
# [LightGBM] [Info] Start training from score -5.747251
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.074506 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 252948
# [LightGBM] [Info] Number of data points in the train set: 4454, number of used features: 2108
# [LightGBM] [Info] Start training from score -5.741644
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.180001 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 252967
# [LightGBM] [Info] Number of data points in the train set: 4455, number of used features: 2109
# [LightGBM] [Info] Start training from score -5.751882
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.081327 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 252937
# [LightGBM] [Info] Number of data points in the train set: 4455, number of used features: 2104
# [LightGBM] [Info] Start training from score -5.726702
# 0.6863472669609281
# 0.6535118976559224
# 0.6821448701455823
# 0.6796194647065166
# 0.640865731606571
# 0.6871205312614618
# 0.6877942806969264
# 0.4244832809889152
# 0.6391465020370057
# 0.6728329394789558
# 0.5838341981399178
#                           Train MSE (5 fold cv) Train MAE (5 fold cv)  \
# LGBMRegressor                            0.1288                0.2609
# DecisionTreeRegressor                    0.2720                0.3786
# RandomForestRegressor                    0.1326                0.2642
# GradientBoostingRegressor                0.1299                0.2644
# AdaBoostRegressor                        0.1697                0.3229
# XGBRegressor                             0.1492                0.2813
# ExtraTreesRegressor                      0.1352                0.2646
# LinearRegression                         0.6014                0.4391
# KNeighborsRegressor                      0.1908                0.3176
# SVR                                      0.1490                0.2769
# MLPRegressor                             0.2948                0.3957
#
#                           Train RMSE (5 fold cv) Train R2 (5 fold cv)  \
# LGBMRegressor                             0.3589               0.7932
# DecisionTreeRegressor                     0.5215               0.5633
# RandomForestRegressor                     0.3642               0.7870
# GradientBoostingRegressor                 0.3605               0.7914
# AdaBoostRegressor                         0.4120               0.7275
# XGBRegressor                              0.3863               0.7604
# ExtraTreesRegressor                       0.3677               0.7830
# LinearRegression                          0.7755               0.0343
# KNeighborsRegressor                       0.4369               0.6936
# SVR                                       0.3860               0.7608
# MLPRegressor                              0.5430               0.5266
#
#                           Train PCC (5 fold cv) Train SCC (5 fold cv)  \
# LGBMRegressor                            0.8906                0.8738
# DecisionTreeRegressor                    0.7832                0.7620
# RandomForestRegressor                    0.8872                0.8693
# GradientBoostingRegressor                0.8896                0.8689
# AdaBoostRegressor                        0.8612                0.8329
# XGBRegressor                             0.8732                0.8549
# ExtraTreesRegressor                      0.8849                0.8686
# LinearRegression                         0.6303                0.7483
# KNeighborsRegressor                      0.8360                0.8131
# SVR                                      0.8728                0.8588
# MLPRegressor                             0.7657                0.7578
#
#                           Test MSE Test MAE Test RMSE Test R2  \
# LGBMRegressor               0.1985   0.3147    0.4455  0.6863
# DecisionTreeRegressor       0.2193   0.3358    0.4683  0.6535
# RandomForestRegressor       0.2011   0.3169    0.4485  0.6821
# GradientBoostingRegressor   0.2027   0.3194    0.4503  0.6796
# AdaBoostRegressor           0.2273   0.3650    0.4767  0.6409
# XGBRegressor                0.1980   0.3115    0.4450  0.6871
# ExtraTreesRegressor         0.1976   0.3149    0.4445  0.6878
# LinearRegression            0.3642   0.3899    0.6035  0.4245
# KNeighborsRegressor         0.2284   0.3371    0.4779  0.6391
# SVR                         0.2070   0.3213    0.4550  0.6728
# MLPRegressor                0.2634   0.3653    0.5132  0.5838
#
#                           Test Pearson Correlation Test Spearman Correlation
# LGBMRegressor                               0.8286                    0.8124
# DecisionTreeRegressor                       0.8106                    0.7844
# RandomForestRegressor                       0.8260                    0.8087
# GradientBoostingRegressor                   0.8247                    0.8051
# AdaBoostRegressor                           0.8074                    0.7814
# XGBRegressor                                0.8293                    0.8152
# ExtraTreesRegressor                         0.8294                    0.8127
# LinearRegression                            0.7083                    0.7477
# KNeighborsRegressor                         0.8026                    0.7938
# SVR                                         0.8208                    0.8087
# MLPRegressor                                0.7762                    0.7620

# %%
result_df.to_csv('/home/users/akshay/PCPpred/PAMPA/Results/combined_features/combined_features_pampa.csv')
prediction_df.to_csv('/home/users/akshay/PCPpred/PAMPA/Results/combined_features/prediction_data_combined_features_pampa.csv')

# %%
X = train.drop(columns=['ID', 'SMILES', 'Permeability'])
y = train['Permeability']

rf = RandomForestRegressor(n_estimators=100, random_state=101, n_jobs=-1)
rf.fit(X, y)

importances = rf.feature_importances_
feature_names = X.columns

# %%
#Top 10 features
n = 10  
top_10_indices = importances.argsort()[::-1][:n]  # indices of top n features
top_10_features = feature_names[top_10_indices].tolist()  # convert to list

# Output the list
print("Top", 10, "features:\n")
print(top_10_features)

train_df = pd.concat([train[['ID', 'SMILES', 'Permeability']], X[top_10_features]], axis=1)
test_df = test[train.columns]
# Out:
# Top 10 features:
#
# ['x_fine_emb_MFXL143', 'x_fine_emb_MFXL23', 'x_fine_emb_MFXL686', 'x_fine_emb_MFXL139', 'x_fine_emb_MFXL0', 'x_fine_emb_MFXL448', 'x_fine_emb_MFXL208', 'x_fine_emb_MFXL730', 'x_fine_emb_MFXL556', 'x_fine_emb_MFXL149']

# %%
X_train = train_df.drop(['ID','SMILES','Permeability'],axis=1)
y_train = train_df['Permeability']
print("X_train shape: ",X_train.shape)
print("y_train shape: ",y_train.shape)
print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
X_test = test_df[X_train.columns]
y_test = test_df['Permeability']
print("X_test shape: ",X_test.shape)
print("y_test shape: ",y_test.shape)
print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
print('Features: ', X_train.columns)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_train = pd.DataFrame(X_train_scaled, columns=X_train.columns, index=X_train.index)
X_test = pd.DataFrame(X_test_scaled, columns=X_test.columns, index=X_test.index)
models = [
    lgb.LGBMRegressor(objective='regression',metric='rmse',boosting_type='gbdt',num_leaves=31,learning_rate=0.05,random_state=101),
    DecisionTreeRegressor(random_state=101),
    RandomForestRegressor(n_jobs=-1, random_state=101),
    GradientBoostingRegressor(random_state=101),
    AdaBoostRegressor(random_state=101),
    xgb.XGBRegressor(random_state=101),
    ExtraTreesRegressor(n_jobs=-1, n_estimators=100, random_state=101),
    LinearRegression(), 
    KNeighborsRegressor(n_neighbors=3),
    SVR(),  
    MLPRegressor(random_state=101)
]
result_df, prediction_df = train_and_test_predict(models, X_train,y_train, X_test,  y_test)
result_df
# Out:
# X_train shape:  (5568, 10)
# y_train shape:  (5568,)
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# X_test shape:  (1392, 10)
# y_test shape:  (1392,)
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# Features:  Index(['x_fine_emb_MFXL143', 'x_fine_emb_MFXL23', 'x_fine_emb_MFXL686',
#        'x_fine_emb_MFXL139', 'x_fine_emb_MFXL0', 'x_fine_emb_MFXL448',
#        'x_fine_emb_MFXL208', 'x_fine_emb_MFXL730', 'x_fine_emb_MFXL556',
#        'x_fine_emb_MFXL149'],
#       dtype='object')
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000620 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 4454, number of used features: 10
# [LightGBM] [Info] Start training from score -5.747051
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000579 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 4454, number of used features: 10
# [LightGBM] [Info] Start training from score -5.747251
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000540 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 4454, number of used features: 10
# [LightGBM] [Info] Start training from score -5.741644
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000554 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 4455, number of used features: 10
# [LightGBM] [Info] Start training from score -5.751882
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000597 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2550
# [LightGBM] [Info] Number of data points in the train set: 4455, number of used features: 10
# [LightGBM] [Info] Start training from score -5.726702
# 0.655756556084484
# 0.620033316966094
# 0.6633454035459665
# 0.6502595820946933
# 0.5839862362794674
# 0.6539204815167463
# 0.6670738948748102
# 0.6399987225093654
# 0.6447222152442822
# 0.6457593737965306
# /home/users/akshay/anaconda3/envs/py312/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/users/akshay/anaconda3/envs/py312/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/users/akshay/anaconda3/envs/py312/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 0.6459508851818214
#                           Train MSE (5 fold cv) Train MAE (5 fold cv)  \
# LGBMRegressor                            0.1395                0.2774
# DecisionTreeRegressor                    0.2859                0.3908
# RandomForestRegressor                    0.1421                0.2781
# GradientBoostingRegressor                0.1400                0.2796
# AdaBoostRegressor                        0.2016                0.3528
# XGBRegressor                             0.1569                0.2931
# ExtraTreesRegressor                      0.1422                0.2758
# LinearRegression                         0.1415                0.2815
# KNeighborsRegressor                      0.1670                0.2989
# SVR                                      0.1371                0.2722
# MLPRegressor                             0.1408                0.2795
#
#                           Train RMSE (5 fold cv) Train R2 (5 fold cv)  \
# LGBMRegressor                             0.3735               0.7761
# DecisionTreeRegressor                     0.5347               0.5410
# RandomForestRegressor                     0.3770               0.7718
# GradientBoostingRegressor                 0.3741               0.7753
# AdaBoostRegressor                         0.4490               0.6763
# XGBRegressor                              0.3961               0.7480
# ExtraTreesRegressor                       0.3771               0.7717
# LinearRegression                          0.3761               0.7729
# KNeighborsRegressor                       0.4087               0.7318
# SVR                                       0.3702               0.7799
# MLPRegressor                              0.3752               0.7740
#
#                           Train PCC (5 fold cv) Train SCC (5 fold cv)  \
# LGBMRegressor                            0.8809                0.8577
# DecisionTreeRegressor                    0.7743                0.7447
# RandomForestRegressor                    0.8786                0.8572
# GradientBoostingRegressor                0.8805                0.8548
# AdaBoostRegressor                        0.8363                0.8073
# XGBRegressor                             0.8662                0.8453
# ExtraTreesRegressor                      0.8786                0.8597
# LinearRegression                         0.8791                0.8538
# KNeighborsRegressor                      0.8576                0.8332
# SVR                                      0.8835                0.8595
# MLPRegressor                             0.8799                0.8555
#
#                           Test MSE Test MAE Test RMSE Test R2  \
# LGBMRegressor               0.2178   0.3359    0.4667  0.6558
# DecisionTreeRegressor       0.2405   0.3541    0.4904  0.6200
# RandomForestRegressor       0.2130   0.3316    0.4616  0.6633
# GradientBoostingRegressor   0.2213   0.3383    0.4705  0.6503
# AdaBoostRegressor           0.2633   0.3976    0.5131  0.5840
# XGBRegressor                0.2190   0.3354    0.4680  0.6539
# ExtraTreesRegressor         0.2107   0.3290    0.4590  0.6671
# LinearRegression            0.2278   0.3481    0.4773  0.6400
# KNeighborsRegressor         0.2248   0.3361    0.4742  0.6447
# SVR                         0.2242   0.3385    0.4735  0.6458
# MLPRegressor                0.2241   0.3433    0.4733  0.6460
#
#                           Test Pearson Correlation Test Spearman Correlation
# LGBMRegressor                               0.8101                    0.7894
# DecisionTreeRegressor                       0.7916                    0.7633
# RandomForestRegressor                       0.8147                    0.7929
# GradientBoostingRegressor                   0.8069                    0.7839
# AdaBoostRegressor                           0.7762                    0.7588
# XGBRegressor                                0.8096                    0.7876
# ExtraTreesRegressor                         0.8169                    0.7967
# LinearRegression                            0.8008                    0.7757
# KNeighborsRegressor                         0.8057                    0.7855
# SVR                                         0.8050                    0.7840
# MLPRegressor                                0.8047                    0.7812

# %%
result_df.to_csv('/home/users/akshay/PCPpred/PAMPA/Results/combined_features/combined_top_10_features_pampa.csv')
prediction_df.to_csv('/home/users/akshay/PCPpred/PAMPA/Results/combined_features/prediction_data_combined_top_10_features_pampa.csv')

# %%
#Top 20 features
n = 20  
top_20_indices = importances.argsort()[::-1][:n]  # indices of top n features
top_20_features = feature_names[top_20_indices].tolist()  # convert to list

# Output the list
print("Top", 20, "features:\n")
print(top_20_features)

train_df = pd.concat([train[['ID', 'SMILES', 'Permeability']], X[top_20_features]], axis=1)
test_df = test[train.columns]
# Out:
# Top 20 features:
#
# ['x_fine_emb_MFXL143', 'x_fine_emb_MFXL23', 'x_fine_emb_MFXL686', 'x_fine_emb_MFXL139', 'x_fine_emb_MFXL0', 'x_fine_emb_MFXL448', 'x_fine_emb_MFXL208', 'x_fine_emb_MFXL730', 'x_fine_emb_MFXL556', 'x_fine_emb_MFXL149', 'x_fine_emb_MFXL361', 'x_fine_emb_MFXL148', 'x_fine_emb_MFXL543', 'x_fine_emb_MFXL4', 'x_fine_emb_MFXL166', 'x_fine_emb_MFXL395', 'x_fine_emb_MFXL128', 'x_fine_emb_MFXL519', 'x_fine_emb_MFXL499', 'x_fine_emb_MFXL14']

# %%
X_train = train_df.drop(['ID','SMILES','Permeability'],axis=1)
y_train = train_df['Permeability']
print("X_train shape: ",X_train.shape)
print("y_train shape: ",y_train.shape)
print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
X_test = test_df[X_train.columns]
y_test = test_df['Permeability']
print("X_test shape: ",X_test.shape)
print("y_test shape: ",y_test.shape)
print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
print('Features: ', X_train.columns)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_train = pd.DataFrame(X_train_scaled, columns=X_train.columns, index=X_train.index)
X_test = pd.DataFrame(X_test_scaled, columns=X_test.columns, index=X_test.index)
models = [
    lgb.LGBMRegressor(objective='regression',metric='rmse',boosting_type='gbdt',num_leaves=31,learning_rate=0.05,random_state=101),
    DecisionTreeRegressor(random_state=101),
    RandomForestRegressor(n_jobs=-1, random_state=101),
    GradientBoostingRegressor(random_state=101),
    AdaBoostRegressor(random_state=101),
    xgb.XGBRegressor(random_state=101),
    ExtraTreesRegressor(n_jobs=-1, n_estimators=100, random_state=101),
    LinearRegression(), 
    KNeighborsRegressor(n_neighbors=3),
    SVR(),  
    MLPRegressor(random_state=101)
]
result_df, prediction_df = train_and_test_predict(models, X_train,y_train, X_test,  y_test)
result_df
# Out:
# X_train shape:  (5568, 20)
# y_train shape:  (5568,)
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# X_test shape:  (1392, 20)
# y_test shape:  (1392,)
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# Features:  Index(['x_fine_emb_MFXL143', 'x_fine_emb_MFXL23', 'x_fine_emb_MFXL686',
#        'x_fine_emb_MFXL139', 'x_fine_emb_MFXL0', 'x_fine_emb_MFXL448',
#        'x_fine_emb_MFXL208', 'x_fine_emb_MFXL730', 'x_fine_emb_MFXL556',
#        'x_fine_emb_MFXL149', 'x_fine_emb_MFXL361', 'x_fine_emb_MFXL148',
#        'x_fine_emb_MFXL543', 'x_fine_emb_MFXL4', 'x_fine_emb_MFXL166',
#        'x_fine_emb_MFXL395', 'x_fine_emb_MFXL128', 'x_fine_emb_MFXL519',
#        'x_fine_emb_MFXL499', 'x_fine_emb_MFXL14'],
#       dtype='object')
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001370 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 4454, number of used features: 20
# [LightGBM] [Info] Start training from score -5.747051
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000846 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 4454, number of used features: 20
# [LightGBM] [Info] Start training from score -5.747251
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000843 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 4454, number of used features: 20
# [LightGBM] [Info] Start training from score -5.741644
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000834 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 4455, number of used features: 20
# [LightGBM] [Info] Start training from score -5.751882
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000921 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5100
# [LightGBM] [Info] Number of data points in the train set: 4455, number of used features: 20
# [LightGBM] [Info] Start training from score -5.726702
# 0.6636722307259797
# 0.6256788927002594
# 0.6676647959530486
# 0.6527166963653648
# 0.5939460167487978
# 0.6633618162486573
# 0.6713168546114914
# 0.6421221512947805
# 0.6587825134804588
# 0.6642183064269302
# /home/users/akshay/anaconda3/envs/py312/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/users/akshay/anaconda3/envs/py312/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 0.6468227331924721
#                           Train MSE (5 fold cv) Train MAE (5 fold cv)  \
# LGBMRegressor                            0.1343                0.2704
# DecisionTreeRegressor                    0.2730                0.3813
# RandomForestRegressor                    0.1371                0.2717
# GradientBoostingRegressor                0.1373                0.2753
# AdaBoostRegressor                        0.1947                0.3469
# XGBRegressor                             0.1538                0.2888
# ExtraTreesRegressor                      0.1398                0.2704
# LinearRegression                         0.1384                0.2781
# KNeighborsRegressor                      0.1619                0.2929
# SVR                                      0.1320                0.2663
# MLPRegressor                             0.1395                0.2783
#
#                           Train RMSE (5 fold cv) Train R2 (5 fold cv)  \
# LGBMRegressor                             0.3664               0.7844
# DecisionTreeRegressor                     0.5225               0.5617
# RandomForestRegressor                     0.3703               0.7799
# GradientBoostingRegressor                 0.3705               0.7796
# AdaBoostRegressor                         0.4413               0.6873
# XGBRegressor                              0.3922               0.7531
# ExtraTreesRegressor                       0.3739               0.7755
# LinearRegression                          0.3720               0.7778
# KNeighborsRegressor                       0.4024               0.7400
# SVR                                       0.3634               0.7880
# MLPRegressor                              0.3735               0.7760
#
#                           Train PCC (5 fold cv) Train SCC (5 fold cv)  \
# LGBMRegressor                            0.8857                0.8638
# DecisionTreeRegressor                    0.7823                0.7567
# RandomForestRegressor                    0.8832                0.8632
# GradientBoostingRegressor                0.8829                0.8580
# AdaBoostRegressor                        0.8454                0.8143
# XGBRegressor                             0.8690                0.8492
# ExtraTreesRegressor                      0.8808                0.8643
# LinearRegression                         0.8819                0.8584
# KNeighborsRegressor                      0.8634                0.8420
# SVR                                      0.8880                0.8659
# MLPRegressor                             0.8845                0.8617
#
#                           Test MSE Test MAE Test RMSE Test R2  \
# LGBMRegressor               0.2128   0.3299    0.4613  0.6637
# DecisionTreeRegressor       0.2369   0.3482    0.4867  0.6257
# RandomForestRegressor       0.2103   0.3273    0.4586  0.6677
# GradientBoostingRegressor   0.2198   0.3344    0.4688  0.6527
# AdaBoostRegressor           0.2570   0.3936    0.5069  0.5939
# XGBRegressor                0.2130   0.3304    0.4616  0.6634
# ExtraTreesRegressor         0.2080   0.3253    0.4561  0.6713
# LinearRegression            0.2265   0.3460    0.4759  0.6421
# KNeighborsRegressor         0.2159   0.3269    0.4647  0.6588
# SVR                         0.2125   0.3283    0.4610  0.6642
# MLPRegressor                0.2235   0.3391    0.4728  0.6468
#
#                           Test Pearson Correlation Test Spearman Correlation
# LGBMRegressor                               0.8150                    0.7953
# DecisionTreeRegressor                       0.7944                    0.7716
# RandomForestRegressor                       0.8174                    0.7972
# GradientBoostingRegressor                   0.8085                    0.7848
# AdaBoostRegressor                           0.7841                    0.7686
# XGBRegressor                                0.8152                    0.7946
# ExtraTreesRegressor                         0.8196                    0.8006
# LinearRegression                            0.8022                    0.7790
# KNeighborsRegressor                         0.8141                    0.7959
# SVR                                         0.8161                    0.7974
# MLPRegressor                                0.8100                    0.7873

# %%
result_df.to_csv('/home/users/akshay/PCPpred/PAMPA/Results/combined_features/combined_top_20_features_pampa.csv')
prediction_df.to_csv('/home/users/akshay/PCPpred/PAMPA/Results/combined_features/prediction_data_combined_top_20_features_pampa.csv')

# %%
#Top 50 features
n = 50  
top_50_indices = importances.argsort()[::-1][:n]  # indices of top n features
top_50_features = feature_names[top_50_indices].tolist()  # convert to list

# Output the list
print("Top", 50, "features:\n")
print(top_50_features)

train_df = pd.concat([train[['ID', 'SMILES', 'Permeability']], X[top_50_features]], axis=1)
test_df = test[train.columns]
# Out:
# Top 50 features:
#
# ['x_fine_emb_MFXL143', 'x_fine_emb_MFXL23', 'x_fine_emb_MFXL686', 'x_fine_emb_MFXL139', 'x_fine_emb_MFXL0', 'x_fine_emb_MFXL448', 'x_fine_emb_MFXL208', 'x_fine_emb_MFXL730', 'x_fine_emb_MFXL556', 'x_fine_emb_MFXL149', 'x_fine_emb_MFXL361', 'x_fine_emb_MFXL148', 'x_fine_emb_MFXL543', 'x_fine_emb_MFXL4', 'x_fine_emb_MFXL166', 'x_fine_emb_MFXL395', 'x_fine_emb_MFXL128', 'x_fine_emb_MFXL519', 'x_fine_emb_MFXL499', 'x_fine_emb_MFXL14', 'x_fine_emb_MFXL719', 'x_fine_emb_MFXL635', 'x_fine_emb_MFXL700', 'x_fine_emb_MFXL706', 'x_fine_emb_MFXL219', 'x_fine_emb_MFXL407', 'x_fine_emb_MFXL1', 'x_fine_emb_MFXL607', 'x_fine_emb_MFXL340', 'x_fine_emb_MFXL644', 'x_fine_emb_MFXL193', 'x_fine_emb_MFXL404', 'x_fine_emb_MFXL301', 'x_fine_emb_MFXL96', 'x_fine_emb_MFXL330', 'x_fine_emb_MFXL374', 'x_fine_emb_MFXL329', 'x_fine_emb_MFXL192', 'x_fine_emb_MFXL78', 'x_fine_emb_MFXL511', 'x_fine_emb_MFXL121', 'x_fine_emb_MFXL742', 'x_fine_emb_MFXL85', 'x_fine_emb_MFXL251', 'x_fine_emb_MFXL714', 'x_fine_emb_MFXL221', 'x_fine_emb_MFXL12', 'x_fine_emb_MFXL707', 'CrippenLogP', 'x_fine_emb_MFXL40']

# %%
X_train = train_df.drop(['ID','SMILES','Permeability'],axis=1)
y_train = train_df['Permeability']
print("X_train shape: ",X_train.shape)
print("y_train shape: ",y_train.shape)
print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
X_test = test_df[X_train.columns]
y_test = test_df['Permeability']
print("X_test shape: ",X_test.shape)
print("y_test shape: ",y_test.shape)
print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
print('Features: ', X_train.columns)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_train = pd.DataFrame(X_train_scaled, columns=X_train.columns, index=X_train.index)
X_test = pd.DataFrame(X_test_scaled, columns=X_test.columns, index=X_test.index)
models = [
    lgb.LGBMRegressor(objective='regression',metric='rmse',boosting_type='gbdt',num_leaves=31,learning_rate=0.05,random_state=101),
    DecisionTreeRegressor(random_state=101),
    RandomForestRegressor(n_jobs=-1, random_state=101),
    GradientBoostingRegressor(random_state=101),
    AdaBoostRegressor(random_state=101),
    xgb.XGBRegressor(random_state=101),
    ExtraTreesRegressor(n_jobs=-1, n_estimators=100, random_state=101),
    LinearRegression(), 
    KNeighborsRegressor(n_neighbors=3),
    SVR(),  
    MLPRegressor(random_state=101)
]
result_df, prediction_df = train_and_test_predict(models, X_train,y_train, X_test,  y_test)
result_df
# Out:
# X_train shape:  (5568, 50)
# y_train shape:  (5568,)
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# X_test shape:  (1392, 50)
# y_test shape:  (1392,)
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# Features:  Index(['x_fine_emb_MFXL143', 'x_fine_emb_MFXL23', 'x_fine_emb_MFXL686',
#        'x_fine_emb_MFXL139', 'x_fine_emb_MFXL0', 'x_fine_emb_MFXL448',
#        'x_fine_emb_MFXL208', 'x_fine_emb_MFXL730', 'x_fine_emb_MFXL556',
#        'x_fine_emb_MFXL149', 'x_fine_emb_MFXL361', 'x_fine_emb_MFXL148',
#        'x_fine_emb_MFXL543', 'x_fine_emb_MFXL4', 'x_fine_emb_MFXL166',
#        'x_fine_emb_MFXL395', 'x_fine_emb_MFXL128', 'x_fine_emb_MFXL519',
#        'x_fine_emb_MFXL499', 'x_fine_emb_MFXL14', 'x_fine_emb_MFXL719',
#        'x_fine_emb_MFXL635', 'x_fine_emb_MFXL700', 'x_fine_emb_MFXL706',
#        'x_fine_emb_MFXL219', 'x_fine_emb_MFXL407', 'x_fine_emb_MFXL1',
#        'x_fine_emb_MFXL607', 'x_fine_emb_MFXL340', 'x_fine_emb_MFXL644',
#        'x_fine_emb_MFXL193', 'x_fine_emb_MFXL404', 'x_fine_emb_MFXL301',
#        'x_fine_emb_MFXL96', 'x_fine_emb_MFXL330', 'x_fine_emb_MFXL374',
#        'x_fine_emb_MFXL329', 'x_fine_emb_MFXL192', 'x_fine_emb_MFXL78',
#        'x_fine_emb_MFXL511', 'x_fine_emb_MFXL121', 'x_fine_emb_MFXL742',
#        'x_fine_emb_MFXL85', 'x_fine_emb_MFXL251', 'x_fine_emb_MFXL714',
#        'x_fine_emb_MFXL221', 'x_fine_emb_MFXL12', 'x_fine_emb_MFXL707',
#        'CrippenLogP', 'x_fine_emb_MFXL40'],
#       dtype='object')
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.034011 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 12750
# [LightGBM] [Info] Number of data points in the train set: 4454, number of used features: 50
# [LightGBM] [Info] Start training from score -5.747051
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.005694 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12750
# [LightGBM] [Info] Number of data points in the train set: 4454, number of used features: 50
# [LightGBM] [Info] Start training from score -5.747251
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001629 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12750
# [LightGBM] [Info] Number of data points in the train set: 4454, number of used features: 50
# [LightGBM] [Info] Start training from score -5.741644
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001638 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12750
# [LightGBM] [Info] Number of data points in the train set: 4455, number of used features: 50
# [LightGBM] [Info] Start training from score -5.751882
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001801 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 12750
# [LightGBM] [Info] Number of data points in the train set: 4455, number of used features: 50
# [LightGBM] [Info] Start training from score -5.726702
# 0.6799818291668863
# 0.6313943892411348
# 0.6788996020573176
# 0.6724260490330327
# 0.6274722092857046
# 0.674320380778245
# 0.678245925687482
# 0.657339206323252
# 0.6742120523484729
# 0.6822980265698734
# /home/users/akshay/anaconda3/envs/py312/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/users/akshay/anaconda3/envs/py312/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/users/akshay/anaconda3/envs/py312/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 0.6595427355322909
#                           Train MSE (5 fold cv) Train MAE (5 fold cv)  \
# LGBMRegressor                            0.1289                0.2628
# DecisionTreeRegressor                    0.2660                0.3757
# RandomForestRegressor                    0.1331                0.2649
# GradientBoostingRegressor                0.1309                0.2674
# AdaBoostRegressor                        0.1760                0.3302
# XGBRegressor                             0.1455                0.2771
# ExtraTreesRegressor                      0.1353                0.2655
# LinearRegression                         0.1313                0.2695
# KNeighborsRegressor                      0.1566                0.2879
# SVR                                      0.1269                0.2577
# MLPRegressor                             0.1649                0.3026
#
#                           Train RMSE (5 fold cv) Train R2 (5 fold cv)  \
# LGBMRegressor                             0.3590               0.7931
# DecisionTreeRegressor                     0.5158               0.5729
# RandomForestRegressor                     0.3648               0.7864
# GradientBoostingRegressor                 0.3619               0.7898
# AdaBoostRegressor                         0.4196               0.7173
# XGBRegressor                              0.3814               0.7664
# ExtraTreesRegressor                       0.3678               0.7828
# LinearRegression                          0.3623               0.7892
# KNeighborsRegressor                       0.3957               0.7485
# SVR                                       0.3563               0.7962
# MLPRegressor                              0.4061               0.7352
#
#                           Train PCC (5 fold cv) Train SCC (5 fold cv)  \
# LGBMRegressor                            0.8906                0.8705
# DecisionTreeRegressor                    0.7855                0.7609
# RandomForestRegressor                    0.8868                0.8685
# GradientBoostingRegressor                0.8887                0.8668
# AdaBoostRegressor                        0.8599                0.8303
# XGBRegressor                             0.8764                0.8573
# ExtraTreesRegressor                      0.8849                0.8682
# LinearRegression                         0.8884                0.8658
# KNeighborsRegressor                      0.8678                0.8452
# SVR                                      0.8925                0.8739
# MLPRegressor                             0.8605                0.8430
#
#                           Test MSE Test MAE Test RMSE Test R2  \
# LGBMRegressor               0.2025   0.3193    0.4500  0.6800
# DecisionTreeRegressor       0.2333   0.3431    0.4830  0.6314
# RandomForestRegressor       0.2032   0.3203    0.4508  0.6789
# GradientBoostingRegressor   0.2073   0.3236    0.4553  0.6724
# AdaBoostRegressor           0.2357   0.3743    0.4855  0.6275
# XGBRegressor                0.2061   0.3186    0.4540  0.6743
# ExtraTreesRegressor         0.2036   0.3212    0.4512  0.6782
# LinearRegression            0.2168   0.3358    0.4657  0.6573
# KNeighborsRegressor         0.2062   0.3181    0.4541  0.6742
# SVR                         0.2011   0.3162    0.4484  0.6823
# MLPRegressor                0.2155   0.3315    0.4642  0.6595
#
#                           Test Pearson Correlation Test Spearman Correlation
# LGBMRegressor                               0.8248                    0.8054
# DecisionTreeRegressor                       0.7980                    0.7836
# RandomForestRegressor                       0.8241                    0.8055
# GradientBoostingRegressor                   0.8204                    0.7968
# AdaBoostRegressor                           0.8029                    0.7783
# XGBRegressor                                0.8219                    0.8035
# ExtraTreesRegressor                         0.8238                    0.8043
# LinearRegression                            0.8116                    0.7876
# KNeighborsRegressor                         0.8235                    0.8048
# SVR                                         0.8270                    0.8104
# MLPRegressor                                0.8150                    0.7924

# %%
result_df.to_csv('/home/users/akshay/PCPpred/PAMPA/Results/combined_features/combined_top_50_features_pampa.csv')
prediction_df.to_csv('/home/users/akshay/PCPpred/PAMPA/Results/combined_features/prediction_data_combined_top_50_features_pampa.csv')

# %%
#Top 100 features
n = 100  
top_100_indices = importances.argsort()[::-1][:n]  # indices of top n features
top_100_features = feature_names[top_100_indices].tolist()  # convert to list

# Output the list
print("Top", 100, "features:\n")
print(top_100_features)

train_df = pd.concat([train[['ID', 'SMILES', 'Permeability']], X[top_100_features]], axis=1)
test_df = test[train.columns]
# Out:
# Top 100 features:
#
# ['x_fine_emb_MFXL143', 'x_fine_emb_MFXL23', 'x_fine_emb_MFXL686', 'x_fine_emb_MFXL139', 'x_fine_emb_MFXL0', 'x_fine_emb_MFXL448', 'x_fine_emb_MFXL208', 'x_fine_emb_MFXL730', 'x_fine_emb_MFXL556', 'x_fine_emb_MFXL149', 'x_fine_emb_MFXL361', 'x_fine_emb_MFXL148', 'x_fine_emb_MFXL543', 'x_fine_emb_MFXL4', 'x_fine_emb_MFXL166', 'x_fine_emb_MFXL395', 'x_fine_emb_MFXL128', 'x_fine_emb_MFXL519', 'x_fine_emb_MFXL499', 'x_fine_emb_MFXL14', 'x_fine_emb_MFXL719', 'x_fine_emb_MFXL635', 'x_fine_emb_MFXL700', 'x_fine_emb_MFXL706', 'x_fine_emb_MFXL219', 'x_fine_emb_MFXL407', 'x_fine_emb_MFXL1', 'x_fine_emb_MFXL607', 'x_fine_emb_MFXL340', 'x_fine_emb_MFXL644', 'x_fine_emb_MFXL193', 'x_fine_emb_MFXL404', 'x_fine_emb_MFXL301', 'x_fine_emb_MFXL96', 'x_fine_emb_MFXL330', 'x_fine_emb_MFXL374', 'x_fine_emb_MFXL329', 'x_fine_emb_MFXL192', 'x_fine_emb_MFXL78', 'x_fine_emb_MFXL511', 'x_fine_emb_MFXL121', 'x_fine_emb_MFXL742', 'x_fine_emb_MFXL85', 'x_fine_emb_MFXL251', 'x_fine_emb_MFXL714', 'x_fine_emb_MFXL221', 'x_fine_emb_MFXL12', 'x_fine_emb_MFXL707', 'CrippenLogP', 'x_fine_emb_MFXL40', 'x_fine_emb_MFXL455', 'x_fine_emb_MFXL415', 'x_fine_emb_MFXL589', '3d_rdkit_5', 'x_fine_emb_MFXL200', 'x_fine_emb_MFXL205', 'x_fine_emb_MFXL179', 'x_fine_emb_MFXL664', 'x_fine_emb_MFXL31', 'x_fine_emb_MFXL279', 'x_fine_emb_MFXL641', 'x_fine_emb_MFXL188', 'geomShape', 'x_fine_emb_MFXL224', 'x_fine_emb_MFXL646', 'x_fine_emb_MFXL574', 'x_fine_emb_MFXL182', 'x_fine_emb_MFXL486', 'x_fine_emb_MFXL114', '3d_rdkit_9', 'x_fine_emb_MFXL717', '3d_rdkit_10', 'x_fine_emb_MFXL16', 'x_fine_emb_MFXL326', 'x_fine_emb_MFXL189', 'x_fine_emb_MFXL194', 'x_fine_emb_MFXL115', 'x_fine_emb_MFXL685', 'x_fine_emb_MFXL94', 'Ki', 'x_fine_emb_MFXL694', 'x_fine_emb_MFXL360', 'x_fine_emb_MFXL470', 'Dv', 'x_fine_emb_MFXL430', 'x_fine_emb_MFXL673', 'x_fine_emb_MFXL218', 'x_fine_emb_MFXL604', 'x_fine_emb_MFXL335', 'MOMI-XY', 'x_fine_emb_MFXL105', 'x_fine_emb_MFXL150', 'x_fine_emb_MFXL452', 'x_fine_emb_MFXL676', 'TDB9u', 'x_fine_emb_MFXL456', 'x_fine_emb_MFXL130', 'L3p', 'x_fine_emb_MFXL655', 'x_fine_emb_MFXL695']

# %%
X_train = train_df.drop(['ID','SMILES','Permeability'],axis=1)
y_train = train_df['Permeability']
print("X_train shape: ",X_train.shape)
print("y_train shape: ",y_train.shape)
print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
X_test = test_df[X_train.columns]
y_test = test_df['Permeability']
print("X_test shape: ",X_test.shape)
print("y_test shape: ",y_test.shape)
print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
print('Features: ', X_train.columns)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_train = pd.DataFrame(X_train_scaled, columns=X_train.columns, index=X_train.index)
X_test = pd.DataFrame(X_test_scaled, columns=X_test.columns, index=X_test.index)
models = [
    lgb.LGBMRegressor(objective='regression',metric='rmse',boosting_type='gbdt',num_leaves=31,learning_rate=0.05,random_state=101),
    DecisionTreeRegressor(random_state=101),
    RandomForestRegressor(n_jobs=-1, random_state=101),
    GradientBoostingRegressor(random_state=101),
    AdaBoostRegressor(random_state=101),
    xgb.XGBRegressor(random_state=101),
    ExtraTreesRegressor(n_jobs=-1, n_estimators=100, random_state=101),
    LinearRegression(), 
    KNeighborsRegressor(n_neighbors=3),
    SVR(),  
    MLPRegressor(random_state=101)
]
result_df, prediction_df = train_and_test_predict(models, X_train,y_train, X_test,  y_test)
result_df
# Out:
# X_train shape:  (5568, 100)
# y_train shape:  (5568,)
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# X_test shape:  (1392, 100)
# y_test shape:  (1392,)
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# Features:  Index(['x_fine_emb_MFXL143', 'x_fine_emb_MFXL23', 'x_fine_emb_MFXL686',
#        'x_fine_emb_MFXL139', 'x_fine_emb_MFXL0', 'x_fine_emb_MFXL448',
#        'x_fine_emb_MFXL208', 'x_fine_emb_MFXL730', 'x_fine_emb_MFXL556',
#        'x_fine_emb_MFXL149', 'x_fine_emb_MFXL361', 'x_fine_emb_MFXL148',
#        'x_fine_emb_MFXL543', 'x_fine_emb_MFXL4', 'x_fine_emb_MFXL166',
#        'x_fine_emb_MFXL395', 'x_fine_emb_MFXL128', 'x_fine_emb_MFXL519',
#        'x_fine_emb_MFXL499', 'x_fine_emb_MFXL14', 'x_fine_emb_MFXL719',
#        'x_fine_emb_MFXL635', 'x_fine_emb_MFXL700', 'x_fine_emb_MFXL706',
#        'x_fine_emb_MFXL219', 'x_fine_emb_MFXL407', 'x_fine_emb_MFXL1',
#        'x_fine_emb_MFXL607', 'x_fine_emb_MFXL340', 'x_fine_emb_MFXL644',
#        'x_fine_emb_MFXL193', 'x_fine_emb_MFXL404', 'x_fine_emb_MFXL301',
#        'x_fine_emb_MFXL96', 'x_fine_emb_MFXL330', 'x_fine_emb_MFXL374',
#        'x_fine_emb_MFXL329', 'x_fine_emb_MFXL192', 'x_fine_emb_MFXL78',
#        'x_fine_emb_MFXL511', 'x_fine_emb_MFXL121', 'x_fine_emb_MFXL742',
#        'x_fine_emb_MFXL85', 'x_fine_emb_MFXL251', 'x_fine_emb_MFXL714',
#        'x_fine_emb_MFXL221', 'x_fine_emb_MFXL12', 'x_fine_emb_MFXL707',
#        'CrippenLogP', 'x_fine_emb_MFXL40', 'x_fine_emb_MFXL455',
#        'x_fine_emb_MFXL415', 'x_fine_emb_MFXL589', '3d_rdkit_5',
#        'x_fine_emb_MFXL200', 'x_fine_emb_MFXL205', 'x_fine_emb_MFXL179',
#        'x_fine_emb_MFXL664', 'x_fine_emb_MFXL31', 'x_fine_emb_MFXL279',
#        'x_fine_emb_MFXL641', 'x_fine_emb_MFXL188', 'geomShape',
#        'x_fine_emb_MFXL224', 'x_fine_emb_MFXL646', 'x_fine_emb_MFXL574',
#        'x_fine_emb_MFXL182', 'x_fine_emb_MFXL486', 'x_fine_emb_MFXL114',
#        '3d_rdkit_9', 'x_fine_emb_MFXL717', '3d_rdkit_10', 'x_fine_emb_MFXL16',
#        'x_fine_emb_MFXL326', 'x_fine_emb_MFXL189', 'x_fine_emb_MFXL194',
#        'x_fine_emb_MFXL115', 'x_fine_emb_MFXL685', 'x_fine_emb_MFXL94', 'Ki',
#        'x_fine_emb_MFXL694', 'x_fine_emb_MFXL360', 'x_fine_emb_MFXL470', 'Dv',
#        'x_fine_emb_MFXL430', 'x_fine_emb_MFXL673', 'x_fine_emb_MFXL218',
#        'x_fine_emb_MFXL604', 'x_fine_emb_MFXL335', 'MOMI-XY',
#        'x_fine_emb_MFXL105', 'x_fine_emb_MFXL150', 'x_fine_emb_MFXL452',
#        'x_fine_emb_MFXL676', 'TDB9u', 'x_fine_emb_MFXL456',
#        'x_fine_emb_MFXL130', 'L3p', 'x_fine_emb_MFXL655',
#        'x_fine_emb_MFXL695'],
#       dtype='object')
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003051 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 25500
# [LightGBM] [Info] Number of data points in the train set: 4454, number of used features: 100
# [LightGBM] [Info] Start training from score -5.747051
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003164 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 25500
# [LightGBM] [Info] Number of data points in the train set: 4454, number of used features: 100
# [LightGBM] [Info] Start training from score -5.747251
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003247 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 25500
# [LightGBM] [Info] Number of data points in the train set: 4454, number of used features: 100
# [LightGBM] [Info] Start training from score -5.741644
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002958 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 25500
# [LightGBM] [Info] Number of data points in the train set: 4455, number of used features: 100
# [LightGBM] [Info] Start training from score -5.751882
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003092 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 25500
# [LightGBM] [Info] Number of data points in the train set: 4455, number of used features: 100
# [LightGBM] [Info] Start training from score -5.726702
# 0.6804349230994615
# 0.6377431243244538
# 0.6795189953056053
# 0.677715655030241
# 0.6296003866684873
# 0.6783144945951476
# 0.6817020900688613
# 0.6622485096077768
# 0.6580182398790739
# 0.6769263007631668
# /home/users/akshay/anaconda3/envs/py312/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/users/akshay/anaconda3/envs/py312/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 0.6227301560965753
# /home/users/akshay/anaconda3/envs/py312/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
#                           Train MSE (5 fold cv) Train MAE (5 fold cv)  \
# LGBMRegressor                            0.1284                0.2616
# DecisionTreeRegressor                    0.2663                0.3785
# RandomForestRegressor                    0.1319                0.2643
# GradientBoostingRegressor                0.1292                0.2649
# AdaBoostRegressor                        0.1718                0.3250
# XGBRegressor                             0.1462                0.2810
# ExtraTreesRegressor                      0.1329                0.2637
# LinearRegression                         0.1269                0.2644
# KNeighborsRegressor                      0.1626                0.2920
# SVR                                      0.1289                0.2593
# MLPRegressor                             0.1819                0.3219
#
#                           Train RMSE (5 fold cv) Train R2 (5 fold cv)  \
# LGBMRegressor                             0.3583               0.7939
# DecisionTreeRegressor                     0.5160               0.5725
# RandomForestRegressor                     0.3632               0.7882
# GradientBoostingRegressor                 0.3594               0.7926
# AdaBoostRegressor                         0.4144               0.7242
# XGBRegressor                              0.3824               0.7652
# ExtraTreesRegressor                       0.3645               0.7866
# LinearRegression                          0.3562               0.7962
# KNeighborsRegressor                       0.4032               0.7389
# SVR                                       0.3590               0.7931
# MLPRegressor                              0.4266               0.7079
#
#                           Train PCC (5 fold cv) Train SCC (5 fold cv)  \
# LGBMRegressor                            0.8910                0.8718
# DecisionTreeRegressor                    0.7855                0.7614
# RandomForestRegressor                    0.8878                0.8699
# GradientBoostingRegressor                0.8903                0.8692
# AdaBoostRegressor                        0.8605                0.8324
# XGBRegressor                             0.8758                0.8556
# ExtraTreesRegressor                      0.8870                0.8704
# LinearRegression                         0.8923                0.8711
# KNeighborsRegressor                      0.8623                0.8389
# SVR                                      0.8908                0.8736
# MLPRegressor                             0.8476                0.8176
#
#                           Test MSE Test MAE Test RMSE Test R2  \
# LGBMRegressor               0.2022   0.3182    0.4497  0.6804
# DecisionTreeRegressor       0.2292   0.3426    0.4788  0.6377
# RandomForestRegressor       0.2028   0.3197    0.4503  0.6795
# GradientBoostingRegressor   0.2040   0.3216    0.4516  0.6777
# AdaBoostRegressor           0.2344   0.3696    0.4841  0.6296
# XGBRegressor                0.2036   0.3163    0.4512  0.6783
# ExtraTreesRegressor         0.2014   0.3180    0.4488  0.6817
# LinearRegression            0.2137   0.3320    0.4623  0.6622
# KNeighborsRegressor         0.2164   0.3299    0.4652  0.6580
# SVR                         0.2045   0.3183    0.4522  0.6769
# MLPRegressor                0.2387   0.3543    0.4886  0.6227
#
#                           Test Pearson Correlation Test Spearman Correlation
# LGBMRegressor                               0.8251                    0.8063
# DecisionTreeRegressor                       0.8011                    0.7799
# RandomForestRegressor                       0.8244                    0.8068
# GradientBoostingRegressor                   0.8236                    0.8004
# AdaBoostRegressor                           0.8021                    0.7759
# XGBRegressor                                0.8242                    0.8082
# ExtraTreesRegressor                         0.8258                    0.8086
# LinearRegression                            0.8146                    0.7924
# KNeighborsRegressor                         0.8137                    0.7902
# SVR                                         0.8235                    0.8078
# MLPRegressor                                0.7954                    0.7694

# %%
result_df.to_csv('/home/users/akshay/PCPpred/PAMPA/Results/combined_features/combined_top_100_features_pampa.csv')
prediction_df.to_csv('/home/users/akshay/PCPpred/PAMPA/Results/combined_features/prediction_data_combined_top_100_features_pampa.csv')

# %%
#Top 200 features
n = 200  
top_200_indices = importances.argsort()[::-1][:n]  # indices of top n features
top_200_features = feature_names[top_200_indices].tolist()  # convert to list

# Output the list
print("Top", 200, "features:\n")
print(top_200_features)

train_df = pd.concat([train[['ID', 'SMILES', 'Permeability']], X[top_200_features]], axis=1)
test_df = test[train.columns]
# Out:
# Top 200 features:
#
# ['x_fine_emb_MFXL143', 'x_fine_emb_MFXL23', 'x_fine_emb_MFXL686', 'x_fine_emb_MFXL139', 'x_fine_emb_MFXL0', 'x_fine_emb_MFXL448', 'x_fine_emb_MFXL208', 'x_fine_emb_MFXL730', 'x_fine_emb_MFXL556', 'x_fine_emb_MFXL149', 'x_fine_emb_MFXL361', 'x_fine_emb_MFXL148', 'x_fine_emb_MFXL543', 'x_fine_emb_MFXL4', 'x_fine_emb_MFXL166', 'x_fine_emb_MFXL395', 'x_fine_emb_MFXL128', 'x_fine_emb_MFXL519', 'x_fine_emb_MFXL499', 'x_fine_emb_MFXL14', 'x_fine_emb_MFXL719', 'x_fine_emb_MFXL635', 'x_fine_emb_MFXL700', 'x_fine_emb_MFXL706', 'x_fine_emb_MFXL219', 'x_fine_emb_MFXL407', 'x_fine_emb_MFXL1', 'x_fine_emb_MFXL607', 'x_fine_emb_MFXL340', 'x_fine_emb_MFXL644', 'x_fine_emb_MFXL193', 'x_fine_emb_MFXL404', 'x_fine_emb_MFXL301', 'x_fine_emb_MFXL96', 'x_fine_emb_MFXL330', 'x_fine_emb_MFXL374', 'x_fine_emb_MFXL329', 'x_fine_emb_MFXL192', 'x_fine_emb_MFXL78', 'x_fine_emb_MFXL511', 'x_fine_emb_MFXL121', 'x_fine_emb_MFXL742', 'x_fine_emb_MFXL85', 'x_fine_emb_MFXL251', 'x_fine_emb_MFXL714', 'x_fine_emb_MFXL221', 'x_fine_emb_MFXL12', 'x_fine_emb_MFXL707', 'CrippenLogP', 'x_fine_emb_MFXL40', 'x_fine_emb_MFXL455', 'x_fine_emb_MFXL415', 'x_fine_emb_MFXL589', '3d_rdkit_5', 'x_fine_emb_MFXL200', 'x_fine_emb_MFXL205', 'x_fine_emb_MFXL179', 'x_fine_emb_MFXL664', 'x_fine_emb_MFXL31', 'x_fine_emb_MFXL279', 'x_fine_emb_MFXL641', 'x_fine_emb_MFXL188', 'geomShape', 'x_fine_emb_MFXL224', 'x_fine_emb_MFXL646', 'x_fine_emb_MFXL574', 'x_fine_emb_MFXL182', 'x_fine_emb_MFXL486', 'x_fine_emb_MFXL114', '3d_rdkit_9', 'x_fine_emb_MFXL717', '3d_rdkit_10', 'x_fine_emb_MFXL16', 'x_fine_emb_MFXL326', 'x_fine_emb_MFXL189', 'x_fine_emb_MFXL194', 'x_fine_emb_MFXL115', 'x_fine_emb_MFXL685', 'x_fine_emb_MFXL94', 'Ki', 'x_fine_emb_MFXL694', 'x_fine_emb_MFXL360', 'x_fine_emb_MFXL470', 'Dv', 'x_fine_emb_MFXL430', 'x_fine_emb_MFXL673', 'x_fine_emb_MFXL218', 'x_fine_emb_MFXL604', 'x_fine_emb_MFXL335', 'MOMI-XY', 'x_fine_emb_MFXL105', 'x_fine_emb_MFXL150', 'x_fine_emb_MFXL452', 'x_fine_emb_MFXL676', 'TDB9u', 'x_fine_emb_MFXL456', 'x_fine_emb_MFXL130', 'L3p', 'x_fine_emb_MFXL655', 'x_fine_emb_MFXL695', '3d_rdkit_11', 'x_fine_emb_MFXL491', 'x_fine_emb_MFXL639', 'x_fine_emb_MFXL238', 'x_fine_emb_MFXL481', 'x_fine_emb_MFXL21', 'x_fine_emb_MFXL282', 'x_fine_emb_MFXL254', 'x_fine_emb_MFXL764', 'x_fine_emb_MFXL657', 'x_fine_emb_MFXL564', 'x_fine_emb_MFXL733', 'x_fine_emb_MFXL363', 'x_fine_emb_MFXL585', 'x_fine_emb_MFXL666', 'x_fine_emb_MFXL424', 'x_fine_emb_MFXL331', 'x_fine_emb_MFXL83', 'x_fine_emb_MFXL439', 'x_fine_emb_MFXL364', 'x_fine_emb_MFXL765', 'x_fine_emb_MFXL291', 'x_fine_emb_MFXL278', 'x_fine_emb_MFXL418', 'LOBMAX', 'x_fine_emb_MFXL678', 'x_fine_emb_MFXL723', 'x_fine_emb_MFXL233', 'x_fine_emb_MFXL305', 'x_fine_emb_MFXL38', 'x_fine_emb_MFXL573', 'x_fine_emb_MFXL319', 'TDB6s', 'x_fine_emb_MFXL670', 'x_fine_emb_MFXL227', 'LOBMIN', 'x_fine_emb_MFXL763', 'x_fine_emb_MFXL593', 'x_fine_emb_MFXL421', 'x_fine_emb_MFXL611', 'x_fine_emb_MFXL66', 'x_fine_emb_MFXL350', 'x_fine_emb_MFXL90', 'x_fine_emb_MFXL242', 'x_fine_emb_MFXL627', 'x_fine_emb_MFXL239', 'RPCS', 'x_fine_emb_MFXL155', 'x_fine_emb_MFXL368', 'x_fine_emb_MFXL260', 'x_fine_emb_MFXL93', 'x_fine_emb_MFXL767', 'x_fine_emb_MFXL154', 'x_fine_emb_MFXL53', 'x_fine_emb_MFXL151', 'x_fine_emb_MFXL625', 'x_fine_emb_MFXL243', 'x_fine_emb_MFXL226', 'x_fine_emb_MFXL661', 'x_fine_emb_MFXL702', 'x_fine_emb_MFXL561', 'x_fine_emb_MFXL677', 'x_fine_emb_MFXL675', 'x_fine_emb_MFXL624', 'x_fine_emb_MFXL640', 'x_fine_emb_MFXL476', 'x_fine_emb_MFXL369', 'P1m', 'x_fine_emb_MFXL473', 'x_fine_emb_MFXL215', 'x_fine_emb_MFXL366', 'x_fine_emb_MFXL482', 'x_fine_emb_MFXL389', 'TDB10m', 'x_fine_emb_MFXL91', 'x_fine_emb_MFXL162', 'RDF55p', 'x_fine_emb_MFXL712', 'x_fine_emb_MFXL475', 'x_fine_emb_MFXL440', 'x_fine_emb_MFXL735', 'x_fine_emb_MFXL236', 'x_fine_emb_MFXL124', 'x_fine_emb_MFXL153', 'x_fine_emb_MFXL332', 'x_fine_emb_MFXL387', 'x_fine_emb_MFXL50', 'x_fine_emb_MFXL516', 'x_fine_emb_MFXL74', 'x_fine_emb_MFXL669', 'x_fine_emb_MFXL529', 'x_fine_emb_MFXL159', 'x_fine_ ...

# %%
X_train = train_df.drop(['ID','SMILES','Permeability'],axis=1)
y_train = train_df['Permeability']
print("X_train shape: ",X_train.shape)
print("y_train shape: ",y_train.shape)
print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
X_test = test_df[X_train.columns]
y_test = test_df['Permeability']
print("X_test shape: ",X_test.shape)
print("y_test shape: ",y_test.shape)
print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
print('Features: ', X_train.columns)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_train = pd.DataFrame(X_train_scaled, columns=X_train.columns, index=X_train.index)
X_test = pd.DataFrame(X_test_scaled, columns=X_test.columns, index=X_test.index)
models = [
    lgb.LGBMRegressor(objective='regression',metric='rmse',boosting_type='gbdt',num_leaves=31,learning_rate=0.05,random_state=101),
    DecisionTreeRegressor(random_state=101),
    RandomForestRegressor(n_jobs=-1, random_state=101),
    GradientBoostingRegressor(random_state=101),
    AdaBoostRegressor(random_state=101),
    xgb.XGBRegressor(random_state=101),
    ExtraTreesRegressor(n_jobs=-1, n_estimators=100, random_state=101),
    LinearRegression(), 
    KNeighborsRegressor(n_neighbors=3),
    SVR(),  
    MLPRegressor(random_state=101)
]
result_df, prediction_df = train_and_test_predict(models, X_train,y_train, X_test,  y_test)
result_df
# Out:
# X_train shape:  (5568, 200)
# y_train shape:  (5568,)
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# X_test shape:  (1392, 200)
# y_test shape:  (1392,)
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# Features:  Index(['x_fine_emb_MFXL143', 'x_fine_emb_MFXL23', 'x_fine_emb_MFXL686',
#        'x_fine_emb_MFXL139', 'x_fine_emb_MFXL0', 'x_fine_emb_MFXL448',
#        'x_fine_emb_MFXL208', 'x_fine_emb_MFXL730', 'x_fine_emb_MFXL556',
#        'x_fine_emb_MFXL149',
#        ...
#        'x_fine_emb_MFXL529', 'x_fine_emb_MFXL159', 'x_fine_emb_MFXL605',
#        'x_fine_emb_MFXL48', 'x_fine_emb_MFXL759', 'x_fine_emb_MFXL383',
#        'x_fine_emb_MFXL181', 'x_fine_emb_MFXL525', 'x_fine_emb_MFXL59',
#        'x_fine_emb_MFXL45'],
#       dtype='object', length=200)
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.007971 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 51000
# [LightGBM] [Info] Number of data points in the train set: 4454, number of used features: 200
# [LightGBM] [Info] Start training from score -5.747051
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004418 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 51000
# [LightGBM] [Info] Number of data points in the train set: 4454, number of used features: 200
# [LightGBM] [Info] Start training from score -5.747251
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004593 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 51000
# [LightGBM] [Info] Number of data points in the train set: 4454, number of used features: 200
# [LightGBM] [Info] Start training from score -5.741644
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004492 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 51000
# [LightGBM] [Info] Number of data points in the train set: 4455, number of used features: 200
# [LightGBM] [Info] Start training from score -5.751882
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004201 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 51000
# [LightGBM] [Info] Number of data points in the train set: 4455, number of used features: 200
# [LightGBM] [Info] Start training from score -5.726702
# 0.6818849675064629
# 0.6323840672620734
# 0.6802622053174725
# 0.6786953795114182
# 0.6327790699300682
# 0.6826527445348115
# 0.6848263029458388
# 0.6675743962238563
# 0.6644493663367146
# 0.6791533821755189
# 0.6031180031825238
#                           Train MSE (5 fold cv) Train MAE (5 fold cv)  \
# LGBMRegressor                            0.1294                0.2622
# DecisionTreeRegressor                    0.2726                0.3816
# RandomForestRegressor                    0.1315                0.2638
# GradientBoostingRegressor                0.1296                0.2650
# AdaBoostRegressor                        0.1687                0.3230
# XGBRegressor                             0.1463                0.2796
# ExtraTreesRegressor                      0.1319                0.2628
# LinearRegression                         0.1269                0.2640
# KNeighborsRegressor                      0.1633                0.2935
# SVR                                      0.1307                0.2608
# MLPRegressor                             0.2061                0.3397
#
#                           Train RMSE (5 fold cv) Train R2 (5 fold cv)  \
# LGBMRegressor                             0.3597               0.7922
# DecisionTreeRegressor                     0.5221               0.5624
# RandomForestRegressor                     0.3626               0.7889
# GradientBoostingRegressor                 0.3600               0.7919
# AdaBoostRegressor                         0.4108               0.7291
# XGBRegressor                              0.3825               0.7651
# ExtraTreesRegressor                       0.3632               0.7882
# LinearRegression                          0.3562               0.7963
# KNeighborsRegressor                       0.4041               0.7378
# SVR                                       0.3616               0.7901
# MLPRegressor                              0.4539               0.6691
#
#                           Train PCC (5 fold cv) Train SCC (5 fold cv)  \
# LGBMRegressor                            0.8901                0.8722
# DecisionTreeRegressor                    0.7830                0.7588
# RandomForestRegressor                    0.8882                0.8708
# GradientBoostingRegressor                0.8899                0.8692
# AdaBoostRegressor                        0.8633                0.8327
# XGBRegressor                             0.8757                0.8568
# ExtraTreesRegressor                      0.8878                0.8706
# LinearRegression                         0.8925                0.8720
# KNeighborsRegressor                      0.8614                0.8370
# SVR                                      0.8891                0.8730
# MLPRegressor                             0.8320                0.8089
#
#                           Test MSE Test MAE Test RMSE Test R2  \
# LGBMRegressor               0.2013   0.3175    0.4487  0.6819
# DecisionTreeRegressor       0.2326   0.3445    0.4823  0.6324
# RandomForestRegressor       0.2023   0.3187    0.4498  0.6803
# GradientBoostingRegressor   0.2033   0.3208    0.4509  0.6787
# AdaBoostRegressor           0.2324   0.3689    0.4821  0.6328
# XGBRegressor                0.2008   0.3132    0.4481  0.6827
# ExtraTreesRegressor         0.1995   0.3170    0.4466  0.6848
# LinearRegression            0.2104   0.3289    0.4587  0.6676
# KNeighborsRegressor         0.2123   0.3271    0.4608  0.6644
# SVR                         0.2030   0.3172    0.4506  0.6792
# MLPRegressor                0.2512   0.3549    0.5012  0.6031
#
#                           Test Pearson Correlation Test Spearman Correlation
# LGBMRegressor                               0.8260                    0.8089
# DecisionTreeRegressor                       0.7984                    0.7792
# RandomForestRegressor                       0.8249                    0.8081
# GradientBoostingRegressor                   0.8242                    0.8020
# AdaBoostRegressor                           0.8035                    0.7744
# XGBRegressor                                0.8268                    0.8115
# ExtraTreesRegressor                         0.8276                    0.8106
# LinearRegression                            0.8177                    0.7973
# KNeighborsRegressor                         0.8175                    0.7961
# SVR                                         0.8247                    0.8098
# MLPRegressor                                0.7881                    0.7700

# %%
result_df.to_csv('/home/users/akshay/PCPpred/PAMPA/Results/combined_features/combined_top_200_features_pampa.csv')
prediction_df.to_csv('/home/users/akshay/PCPpred/PAMPA/Results/combined_features/prediction_data_combined_top_200_features_pampa.csv')

# %%
#Top 500 features
n = 500  
top_500_indices = importances.argsort()[::-1][:n]  # indices of top n features
top_500_features = feature_names[top_500_indices].tolist()  # convert to list

# Output the list
print("Top", 500, "features:\n")
print(top_500_features)

train_df = pd.concat([train[['ID', 'SMILES', 'Permeability']], X[top_500_features]], axis=1)
test_df = test[train.columns]
# Out:
# Top 500 features:
#
# ['x_fine_emb_MFXL143', 'x_fine_emb_MFXL23', 'x_fine_emb_MFXL686', 'x_fine_emb_MFXL139', 'x_fine_emb_MFXL0', 'x_fine_emb_MFXL448', 'x_fine_emb_MFXL208', 'x_fine_emb_MFXL730', 'x_fine_emb_MFXL556', 'x_fine_emb_MFXL149', 'x_fine_emb_MFXL361', 'x_fine_emb_MFXL148', 'x_fine_emb_MFXL543', 'x_fine_emb_MFXL4', 'x_fine_emb_MFXL166', 'x_fine_emb_MFXL395', 'x_fine_emb_MFXL128', 'x_fine_emb_MFXL519', 'x_fine_emb_MFXL499', 'x_fine_emb_MFXL14', 'x_fine_emb_MFXL719', 'x_fine_emb_MFXL635', 'x_fine_emb_MFXL700', 'x_fine_emb_MFXL706', 'x_fine_emb_MFXL219', 'x_fine_emb_MFXL407', 'x_fine_emb_MFXL1', 'x_fine_emb_MFXL607', 'x_fine_emb_MFXL340', 'x_fine_emb_MFXL644', 'x_fine_emb_MFXL193', 'x_fine_emb_MFXL404', 'x_fine_emb_MFXL301', 'x_fine_emb_MFXL96', 'x_fine_emb_MFXL330', 'x_fine_emb_MFXL374', 'x_fine_emb_MFXL329', 'x_fine_emb_MFXL192', 'x_fine_emb_MFXL78', 'x_fine_emb_MFXL511', 'x_fine_emb_MFXL121', 'x_fine_emb_MFXL742', 'x_fine_emb_MFXL85', 'x_fine_emb_MFXL251', 'x_fine_emb_MFXL714', 'x_fine_emb_MFXL221', 'x_fine_emb_MFXL12', 'x_fine_emb_MFXL707', 'CrippenLogP', 'x_fine_emb_MFXL40', 'x_fine_emb_MFXL455', 'x_fine_emb_MFXL415', 'x_fine_emb_MFXL589', '3d_rdkit_5', 'x_fine_emb_MFXL200', 'x_fine_emb_MFXL205', 'x_fine_emb_MFXL179', 'x_fine_emb_MFXL664', 'x_fine_emb_MFXL31', 'x_fine_emb_MFXL279', 'x_fine_emb_MFXL641', 'x_fine_emb_MFXL188', 'geomShape', 'x_fine_emb_MFXL224', 'x_fine_emb_MFXL646', 'x_fine_emb_MFXL574', 'x_fine_emb_MFXL182', 'x_fine_emb_MFXL486', 'x_fine_emb_MFXL114', '3d_rdkit_9', 'x_fine_emb_MFXL717', '3d_rdkit_10', 'x_fine_emb_MFXL16', 'x_fine_emb_MFXL326', 'x_fine_emb_MFXL189', 'x_fine_emb_MFXL194', 'x_fine_emb_MFXL115', 'x_fine_emb_MFXL685', 'x_fine_emb_MFXL94', 'Ki', 'x_fine_emb_MFXL694', 'x_fine_emb_MFXL360', 'x_fine_emb_MFXL470', 'Dv', 'x_fine_emb_MFXL430', 'x_fine_emb_MFXL673', 'x_fine_emb_MFXL218', 'x_fine_emb_MFXL604', 'x_fine_emb_MFXL335', 'MOMI-XY', 'x_fine_emb_MFXL105', 'x_fine_emb_MFXL150', 'x_fine_emb_MFXL452', 'x_fine_emb_MFXL676', 'TDB9u', 'x_fine_emb_MFXL456', 'x_fine_emb_MFXL130', 'L3p', 'x_fine_emb_MFXL655', 'x_fine_emb_MFXL695', '3d_rdkit_11', 'x_fine_emb_MFXL491', 'x_fine_emb_MFXL639', 'x_fine_emb_MFXL238', 'x_fine_emb_MFXL481', 'x_fine_emb_MFXL21', 'x_fine_emb_MFXL282', 'x_fine_emb_MFXL254', 'x_fine_emb_MFXL764', 'x_fine_emb_MFXL657', 'x_fine_emb_MFXL564', 'x_fine_emb_MFXL733', 'x_fine_emb_MFXL363', 'x_fine_emb_MFXL585', 'x_fine_emb_MFXL666', 'x_fine_emb_MFXL424', 'x_fine_emb_MFXL331', 'x_fine_emb_MFXL83', 'x_fine_emb_MFXL439', 'x_fine_emb_MFXL364', 'x_fine_emb_MFXL765', 'x_fine_emb_MFXL291', 'x_fine_emb_MFXL278', 'x_fine_emb_MFXL418', 'LOBMAX', 'x_fine_emb_MFXL678', 'x_fine_emb_MFXL723', 'x_fine_emb_MFXL233', 'x_fine_emb_MFXL305', 'x_fine_emb_MFXL38', 'x_fine_emb_MFXL573', 'x_fine_emb_MFXL319', 'TDB6s', 'x_fine_emb_MFXL670', 'x_fine_emb_MFXL227', 'LOBMIN', 'x_fine_emb_MFXL763', 'x_fine_emb_MFXL593', 'x_fine_emb_MFXL421', 'x_fine_emb_MFXL611', 'x_fine_emb_MFXL66', 'x_fine_emb_MFXL350', 'x_fine_emb_MFXL90', 'x_fine_emb_MFXL242', 'x_fine_emb_MFXL627', 'x_fine_emb_MFXL239', 'RPCS', 'x_fine_emb_MFXL155', 'x_fine_emb_MFXL368', 'x_fine_emb_MFXL260', 'x_fine_emb_MFXL93', 'x_fine_emb_MFXL767', 'x_fine_emb_MFXL154', 'x_fine_emb_MFXL53', 'x_fine_emb_MFXL151', 'x_fine_emb_MFXL625', 'x_fine_emb_MFXL243', 'x_fine_emb_MFXL226', 'x_fine_emb_MFXL661', 'x_fine_emb_MFXL702', 'x_fine_emb_MFXL561', 'x_fine_emb_MFXL677', 'x_fine_emb_MFXL675', 'x_fine_emb_MFXL624', 'x_fine_emb_MFXL640', 'x_fine_emb_MFXL476', 'x_fine_emb_MFXL369', 'P1m', 'x_fine_emb_MFXL473', 'x_fine_emb_MFXL215', 'x_fine_emb_MFXL366', 'x_fine_emb_MFXL482', 'x_fine_emb_MFXL389', 'TDB10m', 'x_fine_emb_MFXL91', 'x_fine_emb_MFXL162', 'RDF55p', 'x_fine_emb_MFXL712', 'x_fine_emb_MFXL475', 'x_fine_emb_MFXL440', 'x_fine_emb_MFXL735', 'x_fine_emb_MFXL236', 'x_fine_emb_MFXL124', 'x_fine_emb_MFXL153', 'x_fine_emb_MFXL332', 'x_fine_emb_MFXL387', 'x_fine_emb_MFXL50', 'x_fine_emb_MFXL516', 'x_fine_emb_MFXL74', 'x_fine_emb_MFXL669', 'x_fine_emb_MFXL529', 'x_fine_emb_MFXL159', 'x_fine_ ...

# %%
X_train = train_df.drop(['ID','SMILES','Permeability'],axis=1)
y_train = train_df['Permeability']
print("X_train shape: ",X_train.shape)
print("y_train shape: ",y_train.shape)
print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
X_test = test_df[X_train.columns]
y_test = test_df['Permeability']
print("X_test shape: ",X_test.shape)
print("y_test shape: ",y_test.shape)
print("XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX")
print('Features: ', X_train.columns)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_train = pd.DataFrame(X_train_scaled, columns=X_train.columns, index=X_train.index)
X_test = pd.DataFrame(X_test_scaled, columns=X_test.columns, index=X_test.index)
models = [
    lgb.LGBMRegressor(objective='regression',metric='rmse',boosting_type='gbdt',num_leaves=31,learning_rate=0.05,random_state=101),
    DecisionTreeRegressor(random_state=101),
    RandomForestRegressor(n_jobs=-1, random_state=101),
    GradientBoostingRegressor(random_state=101),
    AdaBoostRegressor(random_state=101),
    xgb.XGBRegressor(random_state=101),
    ExtraTreesRegressor(n_jobs=-1, n_estimators=100, random_state=101),
    LinearRegression(), 
    KNeighborsRegressor(n_neighbors=3),
    SVR(),  
    MLPRegressor(random_state=101)
]
result_df, prediction_df = train_and_test_predict(models, X_train,y_train, X_test,  y_test)
result_df
# Out:
# X_train shape:  (5568, 500)
# y_train shape:  (5568,)
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# X_test shape:  (1392, 500)
# y_test shape:  (1392,)
# XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# Features:  Index(['x_fine_emb_MFXL143', 'x_fine_emb_MFXL23', 'x_fine_emb_MFXL686',
#        'x_fine_emb_MFXL139', 'x_fine_emb_MFXL0', 'x_fine_emb_MFXL448',
#        'x_fine_emb_MFXL208', 'x_fine_emb_MFXL730', 'x_fine_emb_MFXL556',
#        'x_fine_emb_MFXL149',
#        ...
#        'x_fine_emb_MFXL502', 'x_fine_emb_MFXL325', 'x_fine_emb_MFXL352',
#        'x_fine_emb_MFXL84', 'x_fine_emb_MFXL339', 'x_fine_emb_MFXL68',
#        'x_fine_emb_MFXL642', 'x_fine_emb_MFXL572', 'x_fine_emb_MFXL629',
#        'x_fine_emb_MFXL234'],
#       dtype='object', length=500)
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.011797 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 127500
# [LightGBM] [Info] Number of data points in the train set: 4454, number of used features: 500
# [LightGBM] [Info] Start training from score -5.747051
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.011050 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 127500
# [LightGBM] [Info] Number of data points in the train set: 4454, number of used features: 500
# [LightGBM] [Info] Start training from score -5.747251
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.010976 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 127500
# [LightGBM] [Info] Number of data points in the train set: 4454, number of used features: 500
# [LightGBM] [Info] Start training from score -5.741644
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.011382 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 127500
# [LightGBM] [Info] Number of data points in the train set: 4455, number of used features: 500
# [LightGBM] [Info] Start training from score -5.751882
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.011487 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 127500
# [LightGBM] [Info] Number of data points in the train set: 4455, number of used features: 500
# [LightGBM] [Info] Start training from score -5.726702
# 0.685775871991102
# 0.6390796940397304
# 0.6802973357090014
# 0.6788342763117619
# 0.642390893493141
# 0.6864270656049772
# 0.6837322212494036
# 0.6617093513995043
# 0.6651955297333907
# 0.6843342784961466
# 0.599977243403206
#                           Train MSE (5 fold cv) Train MAE (5 fold cv)  \
# LGBMRegressor                            0.1279                0.2600
# DecisionTreeRegressor                    0.2666                0.3749
# RandomForestRegressor                    0.1323                0.2638
# GradientBoostingRegressor                0.1299                0.2653
# AdaBoostRegressor                        0.1682                0.3204
# XGBRegressor                             0.1475                0.2795
# ExtraTreesRegressor                      0.1333                0.2635
# LinearRegression                         0.1312                0.2683
# KNeighborsRegressor                      0.1617                0.2929
# SVR                                      0.1310                0.2598
# MLPRegressor                             0.2152                0.3402
#
#                           Train RMSE (5 fold cv) Train R2 (5 fold cv)  \
# LGBMRegressor                             0.3577               0.7946
# DecisionTreeRegressor                     0.5163               0.5720
# RandomForestRegressor                     0.3637               0.7876
# GradientBoostingRegressor                 0.3604               0.7914
# AdaBoostRegressor                         0.4102               0.7299
# XGBRegressor                              0.3840               0.7632
# ExtraTreesRegressor                       0.3651               0.7860
# LinearRegression                          0.3622               0.7893
# KNeighborsRegressor                       0.4021               0.7404
# SVR                                       0.3619               0.7897
# MLPRegressor                              0.4639               0.6544
#
#                           Train PCC (5 fold cv) Train SCC (5 fold cv)  \
# LGBMRegressor                            0.8914                0.8732
# DecisionTreeRegressor                    0.7860                0.7634
# RandomForestRegressor                    0.8875                0.8699
# GradientBoostingRegressor                0.8896                0.8690
# AdaBoostRegressor                        0.8617                0.8315
# XGBRegressor                             0.8748                0.8597
# ExtraTreesRegressor                      0.8866                0.8701
# LinearRegression                         0.8889                0.8691
# KNeighborsRegressor                      0.8628                0.8403
# SVR                                      0.8888                0.8732
# MLPRegressor                             0.8241                0.8102
#
#                           Test MSE Test MAE Test RMSE Test R2  \
# LGBMRegressor               0.1988   0.3154    0.4459  0.6858
# DecisionTreeRegressor       0.2284   0.3426    0.4779  0.6391
# RandomForestRegressor       0.2023   0.3181    0.4498  0.6803
# GradientBoostingRegressor   0.2032   0.3202    0.4508  0.6788
# AdaBoostRegressor           0.2263   0.3642    0.4757  0.6424
# XGBRegressor                0.1984   0.3122    0.4455  0.6864
# ExtraTreesRegressor         0.2001   0.3171    0.4474  0.6837
# LinearRegression            0.2141   0.3260    0.4627  0.6617
# KNeighborsRegressor         0.2119   0.3270    0.4603  0.6652
# SVR                         0.1998   0.3134    0.4469  0.6843
# MLPRegressor                0.2531   0.3502    0.5031  0.6000
#
#                           Test Pearson Correlation Test Spearman Correlation
# LGBMRegressor                               0.8283                    0.8123
# DecisionTreeRegressor                       0.8022                    0.7848
# RandomForestRegressor                       0.8249                    0.8080
# GradientBoostingRegressor                   0.8242                    0.8045
# AdaBoostRegressor                           0.8080                    0.7796
# XGBRegressor                                0.8289                    0.8139
# ExtraTreesRegressor                         0.8270                    0.8109
# LinearRegression                            0.8150                    0.7988
# KNeighborsRegressor                         0.8181                    0.7990
# SVR                                         0.8277                    0.8143
# MLPRegressor                                0.7839                    0.7658

# %%
result_df.to_csv('/home/users/akshay/PCPpred/PAMPA/Results/combined_features/combined_top_500_features_pampa.csv')
prediction_df.to_csv('/home/users/akshay/PCPpred/PAMPA/Results/combined_features/prediction_data_combined_top_500_features_pampa.csv')
